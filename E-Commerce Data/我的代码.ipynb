# %% [markdown]
# ## 类型: 交易数据分析
# ### 练习重点:
# - EDA (探索性数据分析): 哪个国家的销量最高？什么时间段购物最多？
# - RFM 模型: 根据 Recency (最近一次消费), Frequency (消费频率), Monetary (消费金额) 对用户进行分层。
# - 关联规则挖掘 (Market Basket Analysis): 使用 Apriori 算法发现“买了A商品的人通常也会买B商品”。
# - 为什么推荐: 这是非常真实的业务场景，是数据分析师面试中常见的考题类型。
