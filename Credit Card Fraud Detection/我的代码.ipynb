# %% [markdown]
# ## 类型: 异常检测 / 非平衡分类
# ### 练习重点:
# - 处理类别不平衡 (Imbalanced Data): 正负样本比例极度悬殊，需要学习下采样（Under-sampling）、过采样（SMOTE）等技术。
# - 评估指标: 准确率（Accuracy）在这里失效了，需要掌握 Precision, Recall, F1-Score 和 AUC-ROC。
# - 为什么推荐: 风控是数据挖掘最核心的应用场景之一，这个数据集能让你明白为什么“准确率”有时候是骗人的。
